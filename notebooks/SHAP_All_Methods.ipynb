# %% [markdown]
# # MSc Thesis - SHAP Methods
# - This notebook containes the top 3 SHAP methods I have tested. So far method 1 seems the most promising, followed by method 2 then 3.
# - Method 1 is the newest method I have experimented with. I didn't mention it in Monday's meeting since I didn't finish it yet.

# %%
# Top 3 topics & countries by largest absolute difference between WVS data and LLM moral score
top3_topics = ['for a man to beat his wife',
               'someone accepting a bribe in the course of their duties',
               'terrorism as a political, ideological or religious mean']

top3_countries_in = ['Netherlands', 'New Zealand', 'Germany'] # "in" prompting style
top3_countries_people = ['Libya', 'Maldives', 'Armenia'] # "people" prompting style

# %%
# !pip install --quiet shap
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.5/540.5 kB 3.4 MB/s eta 0:00:00

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import numpy as np

# %%
import shap

# %%
name = 'gpt2'
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModelForCausalLM.from_pretrained(name)

# %% [markdown]
# ## Method 1: Language Modeling
#
# - Aim: get text generation explanations for moral tokens
# - I followed this [example](https://shap.readthedocs.io/en/latest/example_notebooks/text_examples/language_modelling/Language%20Modeling%20Explanation%20Demo.html) and modified the Top-K model form [here](https://github.com/shap/shap/blob/master/shap/models/_topk_lm.py)

# %%
from shap.models import Model
import scipy.special

# %%
class CustomModel(Model):
    """Generates scores (log odds) for the specified tokens for Causal/Masked LM."""

    def __init__(self, model, tokenizer, token_ids, batch_size=128, device=None):
        super().__init__(model)
        self.tokenizer = tokenizer
        self.tokenizer.pad_token = self.tokenizer.eos_token
        self.token_ids = [np.array(ids) for ids in token_ids]
        self.batch_size = batch_size
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') if device is None else torch.device(device)
        self.inner_model = model.to(self.device)
        self.X = None
        self.output_names = None

    def __call__(self, texts):
        masked_X = np.array([text for text in texts])
        X = masked_X.copy()
        output_batch = None
        self.update_cache_X(X[:1])
        start_batch_idx, end_batch_idx = 0, len(masked_X)
        while start_batch_idx < end_batch_idx:
            logits = self.get_lm_logits(masked_X[start_batch_idx:start_batch_idx+self.batch_size])
            logodds = self.get_logodds(logits)
            if output_batch is None:
                output_batch = logodds
            else:
                output_batch = np.concatenate((output_batch, logodds))
            start_batch_idx += self.batch_size
        return output_batch

    def update_cache_X(self, X):
        if (self.X is None) or (not np.array_equal(self.X, X)):
            self.X = X
            self.output_names = self.get_output_names(X)

    def get_output_names(self, X):
        output_names = [self.tokenizer.decode(ids) for ids in self.token_ids]
        return output_names

    def get_logodds(self, logits):
        def calc_logodds(arr):
            probs = np.exp(arr) / np.exp(arr).sum(-1)
            logodds = scipy.special.logit(probs)
            return logodds

        logodds = np.apply_along_axis(calc_logodds, -1, logits)
        logodds_for_token_ids = [np.take(logodds, ids, axis=-1).sum(axis=-1) for ids in self.token_ids]
        return np.stack(logodds_for_token_ids, axis=-1)

    def get_inputs(self, X, padding_side='right'):
        self.tokenizer.padding_side = padding_side
        inputs = self.tokenizer(X.tolist(), return_tensors='pt', padding=True)
        self.tokenizer.padding_side = 'right'
        return inputs

    def get_lm_logits(self, X):
        inputs = self.get_inputs(X, padding_side="left")
        inputs["position_ids"] = (inputs["attention_mask"].long().cumsum(-1) - 1)
        inputs["position_ids"].masked_fill_(inputs["attention_mask"] == 0, 0)
        inputs = inputs.to(self.device)
        with torch.no_grad():
            outputs = self.inner_model(**inputs, return_dict=True)
        logits = outputs.logits.detach().cpu().numpy().astype('float64')[:, -1, :]
        return logits

# %%
moral_id = tokenizer.encode("moral", add_special_tokens=False)
immoral_id = tokenizer.encode("immoral", add_special_tokens=False)

# %%
wrapped_model = CustomModel(model, tokenizer, token_ids=[moral_id, immoral_id])
masker_1 = shap.maskers.Text(tokenizer, mask_token="...", collapse_mask_token=True)

# %%
test1 = ['People in the Netherlands believe terrorism as a political, ideological or religious mean is',
         'People in New Zealand believe terrorism as a political, ideological or religious mean is',
         'People in Germany believe terrorism as a political, ideological or religious mean is']

# %%
explainer = shap.Explainer(wrapped_model, masker_1)

# %%
shap_values_1 = explainer(test1)
# Out:
# PartitionExplainer explainer: 4it [00:12,  4.17s/it]

# %%
shap.plots.text(shap_values_1)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_nogcydefcksxdxuiblsq = '_tp_nogcydefcksxdxuiblsq_output_0';
#     document._zoom_nogcydefcksxdxuiblsq = undefined;
#     function _output_onclick_nogcydefcksxdxuiblsq(i) {
#         var next_id = undefined;
#
#         if (document._zoom_nogcydefcksxdxuiblsq !== undefined) {
#             document.getElementById(document._zoom_nogcydefcksxdxuiblsq+ '_zoom').style.display = 'none';
#
#             if (document._zoom_nogcydefcksxdxuiblsq === '_tp_nogcydefcksxdxuiblsq_output_' + i) {
#                 document.getElementById(document._zoom_nogcydefcksxdxuiblsq).style.display = 'block';
#                 document.getElementById(document._zoom_nogcydefcksxdxuiblsq+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_nogcydefcksxdxuiblsq).style.display = 'none';
#                 document.getElementById(document._zoom_nogcydefcksxdxuiblsq+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_nogcydefcksxdxuiblsq !== '_tp_nogcydefcksxdxuiblsq_output_' + i) {
#             next_id = '_tp_nogcydefcksxdxuiblsq_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_nogcydefcksxdxuiblsq = next_id;
#     }
#     function _output_onmouseover_nogcydefcksxdxuiblsq(i, el) {
#         if (document._zoom_nogcydefcksxdxuiblsq !== undefined) { return; }
#         if (document._hover_nogcydefcksxdxuiblsq !== undefined) {
#             document.getElementById(document._hover_nogcydefcksxdxuiblsq + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_nogcydefcksxdxuiblsq).style.display = 'none';
#         }
#         document.getElementById('_tp_nogcydefcksxdxuiblsq_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_nogcydefcksxdxuiblsq = '_tp_nogcydefcksxdxuiblsq_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.5033868092691621); border-radius: 3px; padding: 0px" id="_tp_nogcydefcksxdxuiblsq_output_0_name"
#     onclick="_output_onclick_nogcydefcksxdxuiblsq(0)"
#     onmouseover="_output_onmouseover_nogcydefcksxdxuiblsq(0, this);">moral</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_nogcydefcksxdxuiblsq_output_1_name"
#     onclick="_output_onclick_nogcydefcksxdxuiblsq(1)"
#     onmouseover="_output_onmouseover_nogcydefcksxdxuiblsq(1, this);">immoral</div><br><br><div id='_tp_nogcydefcksxdxuiblsq_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.395404256564625%" y1="33" x2="51.395404256564625%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.395404256564625%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-25</text><line x1="38.32311077641852%" y1="33" x2="38.32311077641852%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.32311077641852%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-29</text><line x1="25.250817296272416%" y1="33" x2="25.250817296272416%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.250817296272416%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-33</text><line x1="12.178523816126317%" y1="33" x2="12.178523816126317%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.178523816126317%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-37</text><line x1="64.46769773671072%" y1="33" x2="64.46769773671072%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.46769773671072%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-21</text><line x1="77.53999121685683%" y1="33" x2="77.53999121685683%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.53999121685683%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-17</text><line x1="90.61228469700293%" y1="33" x2="90.61228469700293%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.61228469700293%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-13</text><line x1="91.29237585281345%" y1="33" x2="91.29237585281345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.29237585281345%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-12.7919</text><text x="91.29237585281345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-12.7919</text><text x="91.29237585281345%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="71.67453962777117%" y1="33" x2="71.67453962777117%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.67453962777117%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-18.7948</text><text x="71.67453962777117%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-18.7948</text><text x="71.67453962777117%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">moral</tspan>(inputs)</text><rect x="66.42101758742349%" width="5.253522040347678%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="69.79082449753906%" x2="71.67453962777117%" y1="60" y2="60" id="_fb_fcbsmqnervavoqflchhm_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="70.73268206265512%" y="71" font-size="12px" id="_fs_fcbsmqnervavoqflchhm_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.576</text><svg x="69.79082449753906%" y="40" height="20" width="1.8837151302321047%">  <svg x="0" y="0" width="100%" height="100%">    <tex ...

# %% [markdown]
# ## Method 2: Bias Prompting
# - I followed this [example](https://shap.readthedocs.io/en/latest/example_notebooks/text_examples/text_generation/Open%20Ended%20GPT2%20Text%20Generation%20Explanations.html). In particular look at last example.

# %%
def compute_shap_values(x, y, model, tokenizer):
    """
    Compute SHAP values for given X and Y datasets using a specified model.

    Parameters:
        x_data (list): List of input texts (X dataset).
        y_data (list): List of target texts (Y dataset).

    Returns:
        shap_values: Computed SHAP values.
    """
    teacher_forcing_model = shap.models.TeacherForcing(model, tokenizer)
    masker = shap.maskers.Text(tokenizer, mask_token="...", collapse_mask_token=True)
    explainer_2 = shap.Explainer(teacher_forcing_model, masker)

    y_data = generate_y_prompts(y, len(x))
    shap_values = explainer_2(x, y_data)

    return shap_values

def generate_y_prompts(token, count):
    y_prompts = [token for _ in range(count)]
    return y_prompts

# %%
test2 = ['People in the Netherlands believe terrorism as a political, ideological or religious mean is',
         'People in New Zealand believe terrorism as a political, ideological or religious mean is',
         'People in Germany believe terrorism as a political, ideological or religious mean is']

# %%
shap_values_2_moral = compute_shap_values(test2, "moral", model, tokenizer)
shap_values_2_immoral = compute_shap_values(test2, "immoral", model, tokenizer)
# Out:
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer: 4it [00:10, 10.03s/it]

# %%
shap.plots.text(shap_values_2_moral)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_dtufxlzzrpduztjtveet = '_tp_dtufxlzzrpduztjtveet_output_0';
#     document._zoom_dtufxlzzrpduztjtveet = undefined;
#     function _output_onclick_dtufxlzzrpduztjtveet(i) {
#         var next_id = undefined;
#
#         if (document._zoom_dtufxlzzrpduztjtveet !== undefined) {
#             document.getElementById(document._zoom_dtufxlzzrpduztjtveet+ '_zoom').style.display = 'none';
#
#             if (document._zoom_dtufxlzzrpduztjtveet === '_tp_dtufxlzzrpduztjtveet_output_' + i) {
#                 document.getElementById(document._zoom_dtufxlzzrpduztjtveet).style.display = 'block';
#                 document.getElementById(document._zoom_dtufxlzzrpduztjtveet+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_dtufxlzzrpduztjtveet).style.display = 'none';
#                 document.getElementById(document._zoom_dtufxlzzrpduztjtveet+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_dtufxlzzrpduztjtveet !== '_tp_dtufxlzzrpduztjtveet_output_' + i) {
#             next_id = '_tp_dtufxlzzrpduztjtveet_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_dtufxlzzrpduztjtveet = next_id;
#     }
#     function _output_onmouseover_dtufxlzzrpduztjtveet(i, el) {
#         if (document._zoom_dtufxlzzrpduztjtveet !== undefined) { return; }
#         if (document._hover_dtufxlzzrpduztjtveet !== undefined) {
#             document.getElementById(document._hover_dtufxlzzrpduztjtveet + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_dtufxlzzrpduztjtveet).style.display = 'none';
#         }
#         document.getElementById('_tp_dtufxlzzrpduztjtveet_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_dtufxlzzrpduztjtveet = '_tp_dtufxlzzrpduztjtveet_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_dtufxlzzrpduztjtveet_output_0_name"
#     onclick="_output_onclick_dtufxlzzrpduztjtveet(0)"
#     onmouseover="_output_onmouseover_dtufxlzzrpduztjtveet(0, this);">moral</div><br><br><div id='_tp_dtufxlzzrpduztjtveet_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.55079378681429%" y1="33" x2="47.55079378681429%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.55079378681429%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-16</text><line x1="29.688342975969586%" y1="33" x2="29.688342975969586%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.688342975969586%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-18</text><line x1="11.825892165124884%" y1="33" x2="11.825892165124884%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.825892165124884%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-20</text><line x1="65.41324459765899%" y1="33" x2="65.41324459765899%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.41324459765899%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-14</text><line x1="83.2756954085037%" y1="33" x2="83.2756954085037%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.2756954085037%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-12</text><line x1="76.20301368210548%" y1="33" x2="76.20301368210548%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.20301368210548%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-12.7919</text><text x="76.20301368210548%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-12.7919</text><text x="76.20301368210548%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="22.59004140472825%" y1="33" x2="22.59004140472825%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.59004140472825%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-18.7948</text><text x="22.59004140472825%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-18.7948</text><text x="22.59004140472825%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">moral</tspan>(inputs)</text><rect x="8.232754590569467%" width="14.357286814158774%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="17.442095053642724%" x2="22.59004140472825%" y1="60" y2="60" id="_fb_nxtenkwwuvatladuxnrb_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="20.016068229185485%" y="71" font-size="12px" id="_fs_nxtenkwwuvatladuxnrb_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.576</text><svg x="17.442095053642724%" y="40" height="20" width="5.147946351085526%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">believe</text>  </svg></svg><line x1="12.960861898755482%" x2="17.442095053642724%" y1="60" y2="60" id="_fb_nxtenkwwuvatladuxnrb_ind_8" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="15.201478476199103%" y="71" font-size="12px" id="_fs_nxtenkwwuvatladuxnrb_ind_8" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="mid ...

# %%
shap.plots.text(shap_values_2_immoral)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_kdiaezpebexrmijmiurs = '_tp_kdiaezpebexrmijmiurs_output_0';
#     document._zoom_kdiaezpebexrmijmiurs = undefined;
#     function _output_onclick_kdiaezpebexrmijmiurs(i) {
#         var next_id = undefined;
#
#         if (document._zoom_kdiaezpebexrmijmiurs !== undefined) {
#             document.getElementById(document._zoom_kdiaezpebexrmijmiurs+ '_zoom').style.display = 'none';
#
#             if (document._zoom_kdiaezpebexrmijmiurs === '_tp_kdiaezpebexrmijmiurs_output_' + i) {
#                 document.getElementById(document._zoom_kdiaezpebexrmijmiurs).style.display = 'block';
#                 document.getElementById(document._zoom_kdiaezpebexrmijmiurs+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_kdiaezpebexrmijmiurs).style.display = 'none';
#                 document.getElementById(document._zoom_kdiaezpebexrmijmiurs+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_kdiaezpebexrmijmiurs !== '_tp_kdiaezpebexrmijmiurs_output_' + i) {
#             next_id = '_tp_kdiaezpebexrmijmiurs_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_kdiaezpebexrmijmiurs = next_id;
#     }
#     function _output_onmouseover_kdiaezpebexrmijmiurs(i, el) {
#         if (document._zoom_kdiaezpebexrmijmiurs !== undefined) { return; }
#         if (document._hover_kdiaezpebexrmijmiurs !== undefined) {
#             document.getElementById(document._hover_kdiaezpebexrmijmiurs + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_kdiaezpebexrmijmiurs).style.display = 'none';
#         }
#         document.getElementById('_tp_kdiaezpebexrmijmiurs_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_kdiaezpebexrmijmiurs = '_tp_kdiaezpebexrmijmiurs_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_kdiaezpebexrmijmiurs_output_0_name"
#     onclick="_output_onclick_kdiaezpebexrmijmiurs(0)"
#     onmouseover="_output_onmouseover_kdiaezpebexrmijmiurs(0, this);">im</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.47973856209150334); border-radius: 3px; padding: 0px" id="_tp_kdiaezpebexrmijmiurs_output_1_name"
#     onclick="_output_onclick_kdiaezpebexrmijmiurs(1)"
#     onmouseover="_output_onmouseover_kdiaezpebexrmijmiurs(1, this);">moral</div><br><br><div id='_tp_kdiaezpebexrmijmiurs_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.421775721678635%" y1="33" x2="50.421775721678635%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.421775721678635%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="35.78679515840454%" y1="33" x2="35.78679515840454%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.78679515840454%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-13</text><line x1="21.15181459513044%" y1="33" x2="21.15181459513044%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.15181459513044%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-16</text><line x1="65.05675628495273%" y1="33" x2="65.05675628495273%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.05675628495273%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="79.69173684822682%" y1="33" x2="79.69173684822682%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.69173684822682%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="56.59161476822287%" y1="33" x2="56.59161476822287%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="56.59161476822287%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.73526</text><text x="56.59161476822287%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.73526</text><text x="56.59161476822287%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="9.043249888924443%" y1="33" x2="9.043249888924443%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.043249888924443%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-18.4821</text><text x="9.043249888924443%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-18.4821</text><text x="9.043249888924443%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">im</tspan>(inputs)</text><rect x="7.470715110769779%" width="1.5725347781546646%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.364441745701079%" x2="9.043249888924443%" y1="60" y2="60" id="_fb_wxqnxlvaywxodgrshngu_ind_13" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.70384581731276%" y="71" font-size="12px" id="_fs_wxqnxlvaywxodgrshngu_ind_13" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.139</text><svg x="8.364441745701079%" y="40" height="20" width="0.6788081432233639%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">mean</text>  </svg></svg><line x1="7.7211362321277575%" x2="8.364441745701079%" y1="60" y2="60" id="_fb_wxqnxlvaywxodgrshngu_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.042788988914419%" y="71" font-size="12px" id="_fs_wxqnxlvaywxodgrshngu_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.132< ...

# %% [markdown]
# ## Method 3: Perplexity

# %%
def perplexity_metric(lines, model=model, tokenizer=tokenizer, end_with_period=True):
    eos_token = tokenizer.eos_token or tokenizer.sep_token
    if eos_token is None:
        raise ValueError("Neither eos_token nor sep_token is set in the tokenizer.")

    perplexities = []

    for line in lines:
        if end_with_period and not line.endswith('.'):
            line += '.'

        line = eos_token + line

        tokenizer.pad_token = tokenizer.eos_token

        tok_moral = tokenizer(line, return_tensors='pt', padding='longest', add_special_tokens=False)
        input_ids = tok_moral['input_ids']
        attention_mask = tok_moral['attention_mask']

        with torch.no_grad():
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=input_ids)
            loss = outputs.loss
            ppl = torch.exp(loss).item()

        perplexities.append(ppl)

    return perplexities

# %%
test3_moral = ['People in the Netherlands believe terrorism as a political, ideological or religious mean is moral',
         'People in New Zealand believe terrorism as a political, ideological or religious mean is moral',
         'People in Germany believe terrorism as a political, ideological or religious mean is moral']

test3_immoral = ['People in the Netherlands believe terrorism as a political, ideological or religious mean is immoral',
         'People in New Zealand believe terrorism as a political, ideological or religious mean is immoral',
         'People in Germany believe terrorism as a political, ideological or religious mean is immoral']

# %%
test3_moral_perplexity = perplexity_metric(test3_moral)
print(test3_moral_perplexity)
# Out:
# [97.76705932617188, 99.75059509277344, 112.29773712158203]

# %%
test3_immoral_perplexity = perplexity_metric(test3_immoral)
print(test3_immoral_perplexity)
# Out:
# [86.59269714355469, 88.64825439453125, 99.73043060302734]

# %%
explainer_3 = shap.Explainer(perplexity_metric, tokenizer)

# %%
shap_values_3_moral = explainer_3(test3_moral)
shap_values_3_immoral = explainer_3(test3_immoral)
# Out:
#   0%|          | 0/240 [00:00<?, ?it/s]
# PartitionExplainer explainer:  33%|███▎      | 1/3 [00:00<?, ?it/s]
#   0%|          | 0/240 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 3/3 [01:05<00:00, 16.16s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer: 4it [01:34, 31.57s/it]
#   0%|          | 0/240 [00:00<?, ?it/s]
# PartitionExplainer explainer:  33%|███▎      | 1/3 [00:00<?, ?it/s]
#   0%|          | 0/240 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 3/3 [01:14<00:00, 15.16s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer: 4it [01:36, 32.30s/it]

# %%
shap.plots.text(shap_values_3_moral)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="42.117748195693316%" y1="33" x2="42.117748195693316%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="42.117748195693316%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="24.756568237180332%" y1="33" x2="24.756568237180332%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.756568237180332%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1000</text><line x1="7.395388278667345%" y1="33" x2="7.395388278667345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.395388278667345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2000</text><line x1="59.478928154206294%" y1="33" x2="59.478928154206294%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.478928154206294%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1000</text><line x1="76.84010811271928%" y1="33" x2="76.84010811271928%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.84010811271928%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2000</text><line x1="55.9326305810315%" y1="33" x2="55.9326305810315%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="55.9326305810315%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">795.734</text><text x="55.9326305810315%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">795.734</text><text x="55.9326305810315%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="43.8150997066696%" y1="33" x2="43.8150997066696%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="43.8150997066696%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">97.7671</text><text x="43.8150997066696%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">97.7671</text><text x="43.8150997066696%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="10.44128452957882%" width="33.373815177090776%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="34.08043942581937%" x2="43.8150997066696%" y1="60" y2="60" id="_fb_glgyenhtborxsctlykbf_ind_10" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="38.94776956624449%" y="71" font-size="12px" id="_fs_glgyenhtborxsctlykbf_ind_10" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">560.714</text><svg x="34.08043942581937%" y="40" height="20" width="9.734660280850228%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">ideological</text>  </svg></svg><line x1="27.585272116064584%" x2="34.08043942581937%" y1="60" y2="60" id="_fb_glgyenhtborxsctlykbf_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="30.832855770941975%" y="71" font-size="12px" id="_fs_glgyenhtborxsctlykbf_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">374.12</text><svg x="27.585272116064584%" y="40" height="20" width="6.4951673097547875%">  <svg x="0" y="0" width="100%" height="100%">    <t ...

# %%
shap.plots.text(shap_values_3_immoral)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="42.34820868987542%" y1="33" x2="42.34820868987542%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="42.34820868987542%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="25.258103372717024%" y1="33" x2="25.258103372717024%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.258103372717024%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1000</text><line x1="8.167998055558629%" y1="33" x2="8.167998055558629%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.167998055558629%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2000</text><line x1="59.43831400703382%" y1="33" x2="59.43831400703382%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.43831400703382%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1000</text><line x1="76.52841932419221%" y1="33" x2="76.52841932419221%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.52841932419221%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2000</text><line x1="55.94738774762239%" y1="33" x2="55.94738774762239%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="55.94738774762239%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">795.734</text><text x="55.94738774762239%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">795.734</text><text x="55.94738774762239%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="43.82808700375557%" y1="33" x2="43.82808700375557%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="43.82808700375557%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">86.5927</text><text x="43.82808700375557%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">86.5927</text><text x="43.82808700375557%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="10.194188904618683%" width="33.633898099136886%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="33.89245050162938%" x2="43.82808700375557%" y1="60" y2="60" id="_fb_rzhbneuiqszuvxtfrurq_ind_10" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="38.86026875269248%" y="71" font-size="12px" id="_fs_rzhbneuiqszuvxtfrurq_ind_10" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">581.368</text><svg x="33.89245050162938%" y="40" height="20" width="9.935636502126187%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">ideological</text>  </svg></svg><line x1="27.356704337725322%" x2="33.89245050162938%" y1="60" y2="60" id="_fb_rzhbneuiqszuvxtfrurq_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="30.62457741967735%" y="71" font-size="12px" id="_fs_rzhbneuiqszuvxtfrurq_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">382.429</text><svg x="27.356704337725322%" y="40" height="20" width="6.5357461639040615%">  <svg x="0" y="0" width="100%" height="100%"> ...
